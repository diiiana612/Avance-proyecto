# %%
import pandas as pd 
import numpy as np
from sklearn.datasets import load_wine
import seaborn as sns 


from matplotlib import pyplot as plt 
datos = pd.read_excel('CHISCAS.xlsx', header=0)
df = pd.DataFrame(data=datos)
dt = pd.DataFrame(data=datos)
print(df)
print(dt)
df_to_array = df.values
df_to_array = df['ALLSKY_SFC_PAR_TOT'].values
x = df_to_array

df1_to_array = df.values
df1_to_array = df['CLRSKY_SFC_PAR_TOT'].values
y = df1_to_array 

dt_to_array = df.values
dt_to_array = df['T2M'].values
z = dt_to_array

plt.plot(df_to_array,dt_to_array,'g^')
plt.xlabel('Radiacion [W/m^2]')
plt.ylabel('Temperatura °C')
print("Estadisticas descriptivas sobre la prendecion en chiscas boyaca")

plt.plot(df1_to_array,dt_to_array,'g^')
plt.xlabel('Radiacion [W/m^2]')
plt.ylabel('Temperatura °C')
print("Estadisticas descriptivas sobre la prendecion en chiscas boyaca")



datos.shape
#datos.describe() # media, moda y mediana, rango intercuartiles
datos.info()

#sns.pairplot(datos)
#datos.describe()
#datos.info()
# Out:
#        YEAR  MO  DY  HR  PRECTOTCORR  QV2M    T2M  ALLSKY_SFC_PAR_TOT  \
# 0      2018  12  31  19          0.0  9.58   8.17                0.00
# 1      2018  12  31  20          0.0  9.34   7.73                0.00
# 2      2018  12  31  21          0.0  9.03   7.69                0.00
# 3      2018  12  31  22          0.0  8.79   7.57                0.00
# 4      2018  12  31  23          0.0  8.67   7.36                0.00
# ...     ...  ..  ..  ..          ...   ...    ...                 ...
# 26443  2022   1   6  14          0.0  7.87  18.40              271.95
# 26444  2022   1   6  15          0.0  7.93  17.05              178.17
# 26445  2022   1   6  16          0.0  8.24  14.71               88.27
# 26446  2022   1   6  17          0.0  8.73  12.17               11.33
# 26447  2022   1   6  18          0.0  9.09  10.75                0.00
#
#        CLRSKY_SFC_PAR_TOT
# 0                    0.00
# 1                    0.00
# 2                    0.00
# ...

# %%
datos.describe()
# Out:
#                YEAR            MO            DY            HR   PRECTOTCORR  \
# count  26448.000000  26448.000000  26448.000000  26448.000000  26448.000000
# mean    2020.010133      6.493913     15.670788     11.500000      0.104963
# std        0.827124      3.463572      8.825998      6.922317      0.456925
# min     2018.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2019.000000      3.000000      8.000000      5.750000      0.000000
# 50%     2020.000000      7.000000     16.000000     11.500000      0.000000
# 75%     2021.000000     10.000000     23.000000     17.250000      0.060000
# max     2022.000000     12.000000     31.000000     23.000000     22.940000
#
#                QV2M           T2M  ALLSKY_SFC_PAR_TOT  CLRSKY_SFC_PAR_TOT
# count  26448.000000  26448.000000        26448.000000        26448.000000
# mean      10.028301     12.270788           88.793790          134.898196
# ...

# %%
plt.plot(df1_to_array,dt_to_array,'g^')
plt.xlabel('Radiacion [W/m^2]')
plt.ylabel('Temperatura °C')
print("Estadisticas descriptivas sobre la prendecion en chiscas boyaca")
# Out:
# Estadisticas descriptivas sobre la prendecion en chiscas boyaca

# %%
datos.shape
datos.describe() # media, moda y mediana, rango intercuartiles
datos.info()
sns.pairplot(datos)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26448 entries, 0 to 26447
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   YEAR                26448 non-null  int64
#  1   MO                  26448 non-null  int64
#  2   DY                  26448 non-null  int64
#  3   HR                  26448 non-null  int64
#  4   PRECTOTCORR         26448 non-null  float64
#  5   QV2M                26448 non-null  float64
#  6   T2M                 26448 non-null  float64
#  7   ALLSKY_SFC_PAR_TOT  26448 non-null  float64
#  8   CLRSKY_SFC_PAR_TOT  26448 non-null  float64
# dtypes: float64(5), int64(4)
# memory usage: 1.8 MB

# %%
df2_to_array = df.values
df2_to_array = df['QV2M'].values
x = df2_to_array

plt.plot(df2_to_array,dt_to_array,'g^')
plt.xlabel('HUMEDAD')
plt.ylabel('Temperatura °C')
print("Estadisticas descriptivas sobre la prendecion en chiscas boyaca")
# Out:
# Estadisticas descriptivas sobre la prendecion en chiscas boyaca

# %%
df3_to_array = df.values
df3_to_array = df['PRECTOTCORR'].values
x = df3_to_array

plt.plot(df3_to_array,dt_to_array,'g^')
plt.xlabel('PRECIPACION')
plt.ylabel('Temperatura °C')
print("Estadisticas descriptivas sobre la prendecion en chiscas boyaca")
# Out:
# Estadisticas descriptivas sobre la prendecion en chiscas boyaca
